# %%
# 导入包
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import json
import os
import time

# %%
# 定义一个存储DataFrame的函数，包装了to_csv()方法
def df_to_csv(df=None, filepath=None, filename=None, encoding='GBK', retain_index=False):
    """
    params:
        df：DataFrame数据
        filepath：文件存储路径
        filename：文件名
        encoding：文件存储编码格式
        retain_index：是否保留DataFrame的索引
    """
    if not os.path.exists(filepath): # 先判断这个文件夹是否已存在，已存在说明数据时最新的
        os.mkdir(filepath) # 创建时，文件夹名里有时间来区分数据是否为最新
    df.to_csv(filepath + '/' + filename, encoding=encoding, index=retain_index) # 保存到文件夹中

# %%
# 请求头 这里我尽量弄的全一点
headers = {
    'accept-encoding': 'gzip, deflate, br',
    'accept-language':'zh-CN,zh;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'cookie': 'pgv_pvid=7838988661; ptcz=a749c13713fc703b48592a49922470ed1eda1bcc7b68d2cf5be6fa79c731b76d; pgv_pvi=9718182912; RK=vkrweAJtMM; o_cookie=763074310; pac_uid=1_763074310; luin=o0763074310; lskey=000100007d08c463d9cc757cc4c5ae2cf3732897a65bf7de58e88b9524158f61b02e143bcf6124869366ea7d; tvfe_boss_uuid=e1c916f5e5e6e6bd; _txjk_whl_uuid_aa5wayli=58f307f1d8264ccb8aeb92b2f6225b14',
    'referer': 'https://news.qq.com/zt2020/page/feiyan.htm',
    'sec-fetch-dest': 'script',
    'sec-fetch-mode': 'no-cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36 Edg/83.0.478.61'
}
# 由于网址不同需要的请求头也不太一样，故设置两个请求头，注意cookie是一段时间就会改变的，需要手动来改
headers2 = {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'zh-CN,zh;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'Cache-Control': 'max-age=0',
    'Connection': 'keep-alive',
    'Cookie': 'pgv_pvid=7838988661; ptcz=a749c13713fc703b48592a49922470ed1eda1bcc7b68d2cf5be6fa79c731b76d; pgv_pvi=9718182912; RK=vkrweAJtMM; o_cookie=763074310; pac_uid=1_763074310; luin=o0763074310; lskey=000100007d08c463d9cc757cc4c5ae2cf3732897a65bf7de58e88b9524158f61b02e143bcf6124869366ea7d; tvfe_boss_uuid=e1c916f5e5e6e6bd; _txjk_whl_uuid_aa5wayli=58f307f1d8264ccb8aeb92b2f6225b14; uin=o0763074310; skey=@xEkmEQkwn; qqmusic_uin=; qqmusic_key=; qqmusic_fromtag=; pgv_info=ssid=s1515695283',
    'Host': 'api.inews.qq.com',
    'Sec-Fetch-Dest': 'document',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-Site': 'none',
    'Sec-Fetch-User': '?1',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36 Edg/83.0.478.61'
}

# %% [markdown]
# # 所需要的所有url

# %%
# 国内数据
url0 = "https://view.inews.qq.com/g2/getOnsInfo?name=disease_h5"
 # 国内数据（随时间变化）
url1 = "https://view.inews.qq.com/g2/getOnsInfo?name=disease_other"
# 外国数据（比率和排名）
url2 = "https://api.inews.qq.com/newsqa/v1/automation/modules/list?modules=FAutoCountryWeekCompRank,FAutoContinentConfirmStatis,FAutoConfirmMillionRankList,FAutoHealDeadRateRankList"
# 外国数据（排名）
url3 = "https://view.inews.qq.com/g2/getOnsInfo?name=disease_foreign"
# 全球总体数据（随时间变化）
url4 = "https://api.inews.qq.com/newsqa/v1/automation/modules/list?modules=FAutoGlobalStatis,FAutoContinentStatis,FAutoGlobalDailyList,FAutoCountryConfirmAdd"
# 外国数据（按国家或大洲查看）
url5 = "https://api.inews.qq.com/newsqa/v1/automation/foreign/country/ranklist"
# 外国部分国家历史每日数据（随时间变化）
url6 = "https://api.inews.qq.com/newsqa/v1/automation/foreign/daily/list?country="

# %% [markdown]
# # 国内数据

# %%
# url0 = 'https://view.inews.qq.com/g2/getOnsInfo?name=disease_h5
res0 = requests.get(url0, headers=headers) # 请求数据，使用第一种请求头
data0 = json.loads(res0.json()['data']) # 因为data对应的值还是json字符串，还要转成Python字典

# %%
# 提取最后更新时间用于文件名中
# 该时间决定了是否对数据进行爬取，虽然可能外国数据的更新时间与国内的不同
# 但是这里统一，国内数据更新就顺便再爬取外国的数据
last_update_time = data0['lastUpdateTime'].replace(':', '：') # 这里将英文: 替换成中文的: 就可以用于文件名了


# 中文字段名 其实可以不需要，在数据分析处理的时候读取的时候顺便改了也可以，这里只是为了易读
# field_name_cn = {'name': '地区', 'nowConfirm': '现有确诊', 'confirm': '累计确诊', 'suspect': '疑似', 'dead': '死亡', 'deadRate': '死亡率', 'heal': '治愈', 'healRate': '治愈率'}
# 国内数据存储路径
filepath_cn = f"./疫情数据/国内数据 {last_update_time}"
if not os.path.exists(filepath_cn): # 先判断这个文件夹是否已存在，已存在说明数据时最新的
    os.mkdir(filepath_cn) # 创建用最后更新时间来创建文件夹

china_data = {'name': data0['areaTree'][0]['name']} # 新建一个字典，并地区名添加进去
china_data.update(data0['areaTree'][0]['total']) # 合并地区的数据，字典合并字典
provinces_data =  [china_data] # 先创建省份数据列表，后续数据直接追加尽量，列表中的数据都是字典，先把全国的数据添进去

# 各省份的数据都在 data['areaTree'][0]['children']这里，这是个列表，34个省级行政区
provinces = data0['areaTree'][0]['children']
# 遍历这个列表取出每个省的数据和每个地区的数据
for i in provinces:
    # i['total'] 就是每个省的数据，里面的 showRate 和 showHeal 字段是不需要的 等同于这样data['areaTree'][0]['children'][0]['total']
    one_procevice_data = {'name': i['name']} # 将省份的名字先添加进字典
    one_procevice_data.update(i['total']) # 合并具体数据 i['total']是字典型的数据
    provinces_data.append(one_procevice_data) # 向省份列表追加每个省的数据
    
    # 获取省内的各市的数据 省内的数据一次就保存到单独的csv文件中
    districts = i['children']
    districts_data = [one_procevice_data]
    for j in districts:
        one_district_data = {'name': j['name']}
        one_district_data.update(j['total'])
        districts_data.append(one_district_data)
        
    # 将字典构成的列表直接转为DataFrame
    districts_df = pd.DataFrame(districts_data)
    del districts_df['showRate'] # 删除这多余的两列
    del districts_df['showHeal']
    
    # 保存这个省内各市的数据
    # districts_df.rename(columns=field_name_cn, inplace=True) # 把列名改为中文
    df_to_csv(districts_df, filepath_cn+'/各省具体数据', f'{i["name"]}.csv') # 存储各省具体数据
    # districts_df.to_csv(f"{filepath}/{i['name']}.csv", encoding='GBK', retain_index=False) # 保存到文件夹中 

                        
# 将字典构成的列表直接转为DataFrame
provinces_df = pd.DataFrame(provinces_data)                        
del provinces_df['showRate'] # 删除这多余的两列
del provinces_df['showHeal']
                        
# 保存每个省的数据
# provinces_df.rename(columns=field_name_cn, inplace=True) # 把列名改为中文
df_to_csv(provinces_df, filepath_cn, '中国疫情数据.csv')
# provinces_df.to_csv(f"{field_name_cn}/中国.csv", encoding='GBK', retain_index=False) # 保存到文件夹中

# %% [markdown]
# # 国内数据（随时间变化）

# %%
# url1 = 'https://view.inews.qq.com/g2/getOnsInfo?name=disease_other' # 国内数据（随时间变化）
res1 = requests.get(url1, headers=headers)
data1 = json.loads(res1.json()['data']) # 因为data对应的值还是json字符串，还要转成Python字典

# %%
# 该部分可以直接转DataFrame然后存储数据
df_to_csv(pd.DataFrame(data1['chinaDayList']), filepath_cn, '国内历史每日数据.csv')
df_to_csv(pd.DataFrame(data1['chinaDayAddList']), filepath_cn, '国内历史每日新增数据.csv')
df_to_csv(pd.DataFrame(data1['dailyNewAddHistory']), filepath_cn, '历史每日新增数据（湖北、国家、和非湖北）.csv')

# %%
prov_compare = pd.DataFrame(data1['provinceCompare']) # 各省数据比较（现存确诊，新增确诊，死亡，治愈，连续0增天数
prov_compare = pd.DataFrame(prov_compare.values.T, index=prov_compare.columns, columns=prov_compare.index) # 转置
df_to_csv(prov_compare, filepath_cn, '各省今日数据比较.csv', retain_index=True) # 保留索引

# %% [markdown]
# # 外国数据（比率和排名）

# %%
filepath_fg=  f"./疫情数据/外国数据 {last_update_time}"

# url2 = 'https://api.inews.qq.com/newsqa/v1/automation/modules/list?modules=FAutoCountryWeekCompRank,FAutoContinentConfirmStatis,FAutoConfirmMillionRankList,FAutoHealDeadRateRankList'
res2 = requests.get(url2, headers=headers2) # 这里用了headers2
data2 = res2.json()['data']

# %%
# 存储数据直接用 二次包装的to_csv方法 这里并没有修改列名为中文
df_to_csv(pd.DataFrame(data2['FAutoConfirmMillionRankList']), filepath_fg, '外国每百万人确诊数.csv')
df_to_csv(pd.DataFrame(data2['FAutoContinentConfirmStatis']), filepath_fg, '外国累计确诊周增幅.csv')
df_to_csv(pd.DataFrame(data2['FAutoCountryWeekCompRank']), filepath_fg, '外国累计确诊七日增幅.csv')
df_to_csv(pd.DataFrame(data2['FAutoHealDeadRateRankList']['deadHead']), filepath_fg, '外国死亡率前10名.csv')
df_to_csv(pd.DataFrame(data2['FAutoHealDeadRateRankList']['deadTail']), filepath_fg, '外国死亡率后10名.csv')
df_to_csv(pd.DataFrame(data2['FAutoHealDeadRateRankList']['healHead']), filepath_fg, '外国治愈前10名.csv')
df_to_csv(pd.DataFrame(data2['FAutoHealDeadRateRankList']['healTail']), filepath_fg, '外国治愈后10名.csv')

# %% [markdown]
# # 外国数据（排名和部分国家具体行政区数据）

# %%
# url3 = 'https://view.inews.qq.com/g2/getOnsInfo?name=disease_foreign' # 外国数据（排名）
res3 = requests.get(url3, headers=headers)
data3 = json.loads(res3.json()['data']) # 因为data对应的值还是json字符串，还要转成Python字典

# %%
# 存储数据
df_to_csv(pd.DataFrame(data3['importStatis']['TopList']), filepath_cn, '国内输入病例前十省.csv')
df_to_csv(pd.DataFrame(data3['countryAddConfirmRankList']), filepath_fg, '外国24小时新增确诊前10名.csv')
df_to_csv(pd.DataFrame(data3['countryConfirmWeekCompareRankList']), filepath_fg, '外国七天变化排名.csv')

# %%
# 存储部分国家的具体行政区数据数据  不过这里面就几个国家，同
for i in data3['foreignList']: # i为国家的数据
    # 先判断这个国家有没有具体类似我国省这样的行政区的数据，即判断有没有 children 这个字段
    if 'children' in i: # 等同于 in i.keys()
        # 当存在时，可直接转换成DataFrame并存储
        df_to_csv(pd.DataFrame(i['children']), filepath_fg+'/部分国家具体行政区数据', f"{i['name']}-具体行政区数据.csv")

# %% [markdown]
# # 全球总体数据（随时间变化）

# %%
# url4 = "https://api.inews.qq.com/newsqa/v1/automation/modules/list?modules=FAutoGlobalStatis,FAutoContinentStatis,FAutoGlobalDailyList,FAutoCountryConfirmAdd"
res4 = requests.get(url4, headers=headers2) # 这里用了headers2
data4 = res4.json()['data']

# %%
for i in data4['FAutoContinentStatis']: # 各大洲历史每七天的数据统计
    i.update(i.pop('statis')) # 把statis弹出再追加进去就可以直接转成DataFrame
# 存储数据
df_to_csv(pd.DataFrame(data4['FAutoContinentStatis']), filepath_fg, '各大洲历史每七天的数据统计.csv')

# %%
global_daily_data = [] # 存储全球每日数据的列表
for i in data4['FAutoGlobalDailyList']:
    day_data = {'date': i['date']}
    day_data.update(i['all']) # 就all字段中的每日数据追加进去
    global_daily_data.append(day_data)
# 存储数据
df_to_csv(pd.DataFrame(global_daily_data), filepath_fg, '全球历史每日数据.csv') # 转换成DataFrame，并存储到本地

# %% [markdown]
# # 外国数据（按国家或大洲查看）

# %%
# url5 = "https://api.inews.qq.com/newsqa/v1/automation/foreign/country/ranklist"
res5 = requests.get(url5, headers=headers2)
data5 = res5.json()['data']

# %%
# 存储
df_to_csv(pd.DataFrame(data5), filepath_fg, '外国疫情数据（按国家或大洲查看）.csv')

# %%
data5
# Out:
# [{'name': '美国',
#   'continent': '北美洲',
#   'date': '07.14',
#   'isUpdated': True,
#   'confirmAdd': 65488,
#   'confirmAddCut': 0,
#   'confirm': 3479483,
#   'suspect': 0,
#   'dead': 138247,
#   'heal': 1549469,
#   'nowConfirm': 1791767,
#   'confirmCompare': 65488,
#   'nowConfirmCompare': 32638,
#   'healCompare': 32385,
#   'deadCompare': 465},
#  {'name': '巴西',
#   'continent': '南美洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 20286,
#   'confirmAddCut': 0,
#   'confirm': 1884967,
#   'suspect': 0,
#   'dead': 72833,
#   'heal': 1291251,
#   'nowConfirm': 520883,
#   'confirmCompare': 20286,
#   'nowConfirmCompare': -6855,
#   'healCompare': 26408,
#   'deadCompare': 733},
#  {'name': '印度',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 28498,
#   'confirmAddCut': 0,
#   'confirm': 906752,
#   'suspect': 0,
#   'dead': 23727,
#   'heal': 571460,
#   'nowConfirm': 311565,
#   'confirmCompare': 28498,
#   'nowConfirmCompare': 9956,
#   'healCompare': 17989,
#   'deadCompare': 553},
#  {'name': '俄罗斯',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 6240,
#   'confirmAddCut': 0,
#   'confirm': 738787,
#   'suspect': 0,
#   'dead': 11597,
#   'heal': 511958,
#   'nowConfirm': 215232,
#   'confirmCompare': 6240,
#   'nowConfirmCompare': -2725,
#   'healCompare': 8790,
#   'deadCompare': 175},
#  {'name': '秘鲁',
#   'continent': '南美洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 3797,
#   'confirmAddCut': 0,
#   'confirm': 330123,
#   'suspect': 0,
#   'dead': 12054,
#   'heal': 221008,
#   'nowConfirm': 97061,
#   'confirmCompare': 3797,
#   'nowConfirmCompare': -284,
#   'healCompare': 3897,
#   'deadCompare': 184},
#  {'name': '智利',
#   'continent': '南美洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 2616,
#   'confirmAddCut': 0,
#   'confirm': 317657,
#   'suspect': 0,
#   'dead': 7024,
#   'heal': 286556,
#   'nowConfirm': 24077,
#   'confirmCompare': 2616,
#   'nowConfirmCompare': -83,
#   'healCompare': 2654,
#   'deadCompare': 45},
#  {'name': '墨西哥',
#   'continent': '北美洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 4685,
#   'confirmAddCut': 0,
#   'confirm': 304435,
#   'suspect': 0,
#   'dead': 35491,
#   'heal': 240101,
#   'nowConfirm': 28843,
#   'confirmCompare': 4685,
#   'nowConfirmCompare': -996,
#   'healCompare': 5196,
#   'deadCompare': 485},
#  {'name': '西班牙',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': True,
#   'confirmAdd': 681,
#   'confirmAddCut': 0,
#   'confirm': 303033,
#   'suspect': 0,
#   'dead': 28406,
#   'heal': 196958,
#   'nowConfirm': 77669,
#   'confirmCompare': 2045,
#   'nowConfirmCompare': 2042,
#   'healCompare': 0,
#   'deadCompare': 3},
#  {'name': '英国',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 536,
#   'confirmAddCut': 0,
#   'confirm': 291691,
#   'suspect': 0,
#   'dead': 44915,
#   'heal': 1384,
#   'nowConfirm': 245392,
#   'confirmCompare': 536,
#   'nowConfirmCompare': 519,
#   'healCompare': 6,
#   'deadCompare': 11},
#  {'name': '南非',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 11554,
#   'confirmAddCut': 0,
#   'confirm': 287796,
#   'suspect': 0,
#   'dead': 4172,
#   'heal': 138241,
#   'nowConfirm': 145383,
#   'confirmCompare': 11554,
#   'nowConfirmCompare': 8094,
#   'healCompare': 3367,
#   'deadCompare': 93},
#  {'name': '伊朗',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 2521,
#   'confirmAddCut': 0,
#   'confirm': 262173,
#   'suspect': 0,
#   'dead': 13211,
#   'heal': 225270,
#   'nowConfirm': 23692,
#   'confirmCompare': 2521,
#   'nowConfirmCompare': -389,
#   'healCompare': 2731,
#   'deadCompare': 179},
#  {'name': '巴基斯坦',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 1979,
#   'confirmAddCut': 0,
#   'confirm': 253604,
#   'suspect': 0,
#   'dead': 5320,
#   'heal': 170656,
#   'nowConfirm': 77628,
#   'confirmCompare': 1979,
#   'nowConfirmCompare': -6814,
#   'healCompare': 8739,
#   'deadCompare': 54},
#  {'name': '意大利',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 169,
#   'confirmAddCut': 0,
#   'confirm': 243230,
#   'suspect': 0,
#   'dead': 34967,
#   'heal': 195106,
#   'nowConfirm': 13157,
#   'confirmCompare': 169,
#   'nowConfirmCompare': -22,
#   'healCompare': 178,
#   'deadCompare': 13},
#  {'name': '沙特阿拉伯',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 2692,
#   'confirmAddCut': 0,
#   'confirm': 237803,
#   'suspect': 0,
#   'dead': 2283,
#   'heal': 177560,
#   'nowConfirm': 57960,
#   'confirmCompare': 2692,
#   'nowConfirmCompare': -5066,
#   'healCompare': 7718,
#   'deadCompare': 40},
#  {'name': '土耳其',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 1008,
#   'confirmAddCut': 0,
#   'confirm': 214001,
#   'suspect': 0,
#   'dead': 5382,
#   'heal': 195671,
#   'nowConfirm': 12948,
#   'confirmCompare': 1008,
#   'nowConfirmCompare': -167,
#   'healCompare': 1156,
#   'deadCompare': 19},
#  {'name': '法国',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 1625,
#   'confirmAddCut': 0,
#   'confirm': 209640,
#   'suspect': 0,
#   'dead': 30032,
#   'heal': 78722,
#   'nowConfirm': 100886,
#   'confirmCompare': 1625,
#   'nowConfirmCompare': 1391,
#   'healCompare': 209,
#   'deadCompare': 25},
#  {'name': '德国',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 381,
#   'confirmAddCut': 0,
#   'confirm': 200456,
#   'suspect': 0,
#   'dead': 9077,
#   'heal': 185100,
#   'nowConfirm': 6279,
#   'confirmCompare': 381,
#   'nowConfirmCompare': 376,
#   'healCompare': 0,
#   'deadCompare': 5},
#  {'name': '孟加拉',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 3163,
#   'confirmAddCut': 0,
#   'confirm': 190057,
#   'suspect': 0,
#   'dead': 2424,
#   'heal': 103227,
#   'nowConfirm': 84406,
#   'confirmCompare': 3163,
#   'nowConfirmCompare': -1780,
#   'healCompare': 4910,
#   'deadCompare': 33},
#  {'name': '哥伦比亚',
#   'continent': '南美洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 5083,
#   'confirmAddCut': 0,
#   'confirm': 150445,
#   'suspect': 0,
#   'dead': 5634,
#   'heal': 63451,
#   'nowConfirm': 81360,
#   'confirmCompare': 5083,
#   'nowConfirmCompare': 2610,
#   'healCompare': 2265,
#   'deadCompare': 208},
#  {'name': '加拿大',
#   'continent': '北美洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 676,
#   'confirmAddCut': 0,
#   'confirm': 110046,
#   'suspect': 0,
#   'dead': 8836,
#   'heal': 73420,
#   'nowConfirm': 27790,
#   'confirmCompare': 676,
#   'nowConfirmCompare': 203,
#   'healCompare': 466,
#   'deadCompare': 7},
#  {'name': '卡塔尔',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 418,
#   'confirmAddCut': 0,
#   'confirm': 104016,
#   'suspect': 0,
#   'dead': 149,
#   'heal': 100627,
#   'nowConfirm': 3240,
#   'confirmCompare': 418,
#   'nowConfirmCompare': -468,
#   'healCompare': 884,
#   'deadCompare': 2},
#  {'name': '阿根廷',
#   'continent': '南美洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 3099,
#   'confirmAddCut': 0,
#   'confirm': 103265,
#   'suspect': 0,
#   'dead': 1926,
#   'heal': 45467,
#   'nowConfirm': 55872,
#   'confirmCompare': 3099,
#   'nowConfirmCompare': 1738,
#   'healCompare': 1294,
#   'deadCompare': 67},
#  {'name': '埃及',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 931,
#   'confirmAddCut': 0,
#   'confirm': 83001,
#   'suspect': 0,
#   'dead': 3935,
#   'heal': 24975,
#   'nowConfirm': 54091,
#   'confirmCompare': 931,
#   'nowConfirmCompare': 298,
#   'healCompare': 556,
#   'deadCompare': 77},
#  {'name': '伊拉克',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 2022,
#   'confirmAddCut': 0,
#   'confirm': 81757,
#   'suspect': 0,
#   'dead': 3345,
#   'heal': 50782,
#   'nowConfirm': 27630,
#   'confirmCompare': 2022,
#   'nowConfirmCompare': -1857,
#   'healCompare': 3784,
#   'deadCompare': 95},
#  {'name': '印度尼西亚',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 1591,
#   'confirmAddCut': 0,
#   'confirm': 78572,
#   'suspect': 0,
#   'dead': 3710,
#   'heal': 37636,
#   'nowConfirm': 37226,
#   'confirmCompare': 1591,
#   'nowConfirmCompare': 590,
#   'healCompare': 947,
#   'deadCompare': 54},
#  {'name': '瑞典',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 175,
#   'confirmAddCut': 0,
#   'confirm': 76001,
#   'suspect': 0,
#   'dead': 5545,
#   'heal': 4971,
#   'nowConfirm': 65485,
#   'confirmCompare': 175,
#   'nowConfirmCompare': 166,
#   'healCompare': 0,
#   'deadCompare': 9},
#  {'name': '厄瓜多尔',
#   'continent': '南美洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 589,
#   'confirmAddCut': 0,
#   'confirm': 68459,
#   'suspect': 0,
#   'dead': 5063,
#   'heal': 30369,
#   'nowConfirm': 33027,
#   'confirmCompare': 589,
#   'nowConfirmCompare': 487,
#   'healCompare': 86,
#   'deadCompare': 16},
#  {'name': '白俄罗斯',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 155,
#   'confirmAddCut': 0,
#   'confirm': 65269,
#   'suspect': 0,
#   'dead': 474,
#   'heal': 55799,
#   'nowConfirm': 8996,
#   'confirmCompare': 155,
#   'nowConfirmCompare': -158,
#   'healCompare': 307,
#   'deadCompare': 6},
#  {'name': '比利时',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 74,
#   'confirmAddCut': 0,
#   'confirm': 62781,
#   'suspect': 0,
#   'dead': 9787,
#   'heal': 17223,
#   'nowConfirm': 35771,
#   'confirmCompare': 74,
#   'nowConfirmCompare': 42,
#   'healCompare': 27,
#   'deadCompare': 5},
#  {'name': '哈萨克斯坦',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 1856,
#   'confirmAddCut': 0,
#   'confirm': 61755,
#   'suspect': 0,
#   'dead': 375,
#   'heal': 35911,
#   'nowConfirm': 25469,
#   'confirmCompare': 1856,
#   'nowConfirmCompare': 135,
#   'healCompare': 1721,
#   'deadCompare': 0},
#  {'name': '阿曼',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 1389,
#   'confirmAddCut': 0,
#   'confirm': 59568,
#   'suspect': 0,
#   'dead': 273,
#   'heal': 37987,
#   'nowConfirm': 21308,
#   'confirmCompare': 1389,
#   'nowConfirmCompare': 645,
#   'healCompare': 730,
#   'deadCompare': 14},
#  {'name': '菲律宾',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 539,
#   'confirmAddCut': 0,
#   'confirm': 57545,
#   'suspect': 0,
#   'dead': 1603,
#   'heal': 20459,
#   'nowConfirm': 35483,
#   'confirmCompare': 539,
#   'nowConfirmCompare': 447,
#   'healCompare': 88,
#   'deadCompare': 4},
#  {'name': '科威特',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 666,
#   'confirmAddCut': 0,
#   'confirm': 56174,
#   'suspect': 0,
#   'dead': 396,
#   'heal': 46161,
#   'nowConfirm': 9617,
#   'confirmCompare': 666,
#   'nowConfirmCompare': -142,
#   'healCompare': 805,
#   'deadCompare': 3},
#  {'name': '乌克兰',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 646,
#   'confirmAddCut': 0,
#   'confirm': 55931,
#   'suspect': 0,
#   'dead': 1429,
#   'heal': 28021,
#   'nowConfirm': 26481,
#   'confirmCompare': 646,
#   'nowConfirmCompare': -33,
#   'healCompare': 665,
#   'deadCompare': 14},
#  {'name': '阿联酋',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 344,
#   'confirmAddCut': 0,
#   'confirm': 55198,
#   'suspect': 0,
#   'dead': 334,
#   'heal': 45513,
#   'nowConfirm': 9351,
#   'confirmCompare': 344,
#   'nowConfirmCompare': -30,
#   'healCompare': 373,
#   'deadCompare': 1},
#  {'name': '荷兰',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 53,
#   'confirmAddCut': 0,
#   'confirm': 51361,
#   'suspect': 0,
#   'dead': 6154,
#   'heal': 193,
#   'nowConfirm': 45014,
#   'confirmCompare': 53,
#   'nowConfirmCompare': 55,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '玻利维亚',
#   'continent': '南美洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 1063,
#   'confirmAddCut': 0,
#   'confirm': 49250,
#   'suspect': 0,
#   'dead': 1866,
#   'heal': 15294,
#   'nowConfirm': 32090,
#   'confirmCompare': 1063,
#   'nowConfirmCompare': 553,
#   'healCompare': 451,
#   'deadCompare': 59},
#  {'name': '巴拿马',
#   'continent': '北美洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 1540,
#   'confirmAddCut': 0,
#   'confirm': 47173,
#   'suspect': 0,
#   'dead': 932,
#   'heal': 23919,
#   'nowConfirm': 22322,
#   'confirmCompare': 1540,
#   'nowConfirmCompare': 637,
#   'healCompare': 880,
#   'deadCompare': 23},
#  {'name': '葡萄牙',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 46818,
#   'suspect': 0,
#   'dead': 1662,
#   'heal': 31065,
#   'nowConfirm': 14091,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '新加坡',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 347,
#   'confirmAddCut': 0,
#   'confirm': 46630,
#   'suspect': 0,
#   'dead': 26,
#   'heal': 42541,
#   'nowConfirm': 4063,
#   'confirmCompare': 347,
#   'nowConfirmCompare': 91,
#   'healCompare': 256,
#   'deadCompare': 0},
#  {'name': '多米尼加',
#   'continent': '北美洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 974,
#   'confirmAddCut': 0,
#   'confirm': 45506,
#   'suspect': 0,
#   'dead': 903,
#   'heal': 22441,
#   'nowConfirm': 22162,
#   'confirmCompare': 974,
#   'nowConfirmCompare': -14,
#   'healCompare': 982,
#   'deadCompare': 6},
#  {'name': '以色列',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 1364,
#   'confirmAddCut': 0,
#   'confirm': 41235,
#   'suspect': 0,
#   'dead': 368,
#   'heal': 19474,
#   'nowConfirm': 21393,
#   'confirmCompare': 1364,
#   'nowConfirmCompare': 1142,
#   'healCompare': 218,
#   'deadCompare': 4},
#  {'name': '波兰',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 267,
#   'confirmAddCut': 0,
#   'confirm': 38457,
#   'suspect': 0,
#   'dead': 1588,
#   'heal': 27756,
#   'nowConfirm': 9113,
#   'confirmCompare': 267,
#   'nowConfirmCompare': 14,
#   'healCompare': 241,
#   'deadCompare': 12},
#  {'name': '阿富汗',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 285,
#   'confirmAddCut': 0,
#   'confirm': 34740,
#   'suspect': 0,
#   'dead': 1048,
#   'heal': 21454,
#   'nowConfirm': 12238,
#   'confirmCompare': 285,
#   'nowConfirmCompare': 49,
#   'healCompare': 200,
#   'deadCompare': 36},
#  {'name': '罗马尼亚',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 637,
#   'confirmAddCut': 0,
#   'confirm': 33585,
#   'suspect': 0,
#   'dead': 1931,
#   'heal': 21803,
#   'nowConfirm': 9851,
#   'confirmCompare': 637,
#   'nowConfirmCompare': 496,
#   'healCompare': 111,
#   'deadCompare': 30},
#  {'name': '巴林',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 535,
#   'confirmAddCut': 0,
#   'confirm': 33476,
#   'suspect': 0,
#   'dead': 109,
#   'heal': 29099,
#   'nowConfirm': 4268,
#   'confirmCompare': 535,
#   'nowConfirmCompare': -139,
#   'healCompare': 674,
#   'deadCompare': 0},
#  {'name': '尼日利亚',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 595,
#   'confirmAddCut': 0,
#   'confirm': 33153,
#   'suspect': 0,
#   'dead': 744,
#   'heal': 13671,
#   'nowConfirm': 18738,
#   'confirmCompare': 595,
#   'nowConfirmCompare': 367,
#   'healCompare': 224,
#   'deadCompare': 4},
#  {'name': '瑞士',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 70,
#   'confirmAddCut': 0,
#   'confirm': 33016,
#   'suspect': 0,
#   'dead': 1968,
#   'heal': 29600,
#   'nowConfirm': 1448,
#   'confirmCompare': 70,
#   'nowConfirmCompare': 70,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '亚美尼亚',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 339,
#   'confirmAddCut': 0,
#   'confirm': 32490,
#   'suspect': 0,
#   'dead': 581,
#   'heal': 20729,
#   'nowConfirm': 11180,
#   'confirmCompare': 339,
#   'nowConfirmCompare': -533,
#   'healCompare': 864,
#   'deadCompare': 8},
#  {'name': '危地马拉',
#   'continent': '北美洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 387,
#   'confirmAddCut': 0,
#   'confirm': 29742,
#   'suspect': 0,
#   'dead': 1244,
#   'heal': 4321,
#   'nowConfirm': 24177,
#   'confirmCompare': 387,
#   'nowConfirmCompare': 255,
#   'healCompare': 107,
#   'deadCompare': 25},
#  {'name': '洪都拉斯',
#   'continent': '北美洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 489,
#   'confirmAddCut': 0,
#   'confirm': 28579,
#   'suspect': 0,
#   'dead': 789,
#   'heal': 3123,
#   'nowConfirm': 24667,
#   'confirmCompare': 489,
#   'nowConfirmCompare': 308,
#   'healCompare': 166,
#   'deadCompare': 15},
#  {'name': '爱尔兰',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 10,
#   'confirmAddCut': 0,
#   'confirm': 25638,
#   'suspect': 0,
#   'dead': 1746,
#   'heal': 23364,
#   'nowConfirm': 528,
#   'confirmCompare': 10,
#   'nowConfirmCompare': 10,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '加纳',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 470,
#   'confirmAddCut': 0,
#   'confirm': 24988,
#   'suspect': 0,
#   'dead': 139,
#   'heal': 21067,
#   'nowConfirm': 3782,
#   'confirmCompare': 470,
#   'nowConfirmCompare': -410,
#   'healCompare': 880,
#   'deadCompare': 0},
#  {'name': '阿塞拜疆',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 24570,
#   'suspect': 0,
#   'dead': 313,
#   'heal': 15640,
#   'nowConfirm': 8617,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '日本本土',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 325,
#   'confirmAddCut': 0,
#   'confirm': 22422,
#   'suspect': 0,
#   'dead': 984,
#   'heal': 18058,
#   'nowConfirm': 3380,
#   'confirmCompare': 325,
#   'nowConfirmCompare': 325,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '阿尔及利亚',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 494,
#   'confirmAddCut': 0,
#   'confirm': 19689,
#   'suspect': 0,
#   'dead': 1018,
#   'heal': 14019,
#   'nowConfirm': 4652,
#   'confirmCompare': 494,
#   'nowConfirmCompare': 211,
#   'healCompare': 276,
#   'deadCompare': 7},
#  {'name': '摩尔多瓦',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 57,
#   'confirmAddCut': 0,
#   'confirm': 19439,
#   'suspect': 0,
#   'dead': 649,
#   'heal': 12793,
#   'nowConfirm': 5997,
#   'confirmCompare': 57,
#   'nowConfirmCompare': 50,
#   'healCompare': 0,
#   'deadCompare': 7},
#  {'name': '奥地利',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 73,
#   'confirmAddCut': 0,
#   'confirm': 19021,
#   'suspect': 0,
#   'dead': 709,
#   'heal': 17073,
#   'nowConfirm': 1239,
#   'confirmCompare': 73,
#   'nowConfirmCompare': -1,
#   'healCompare': 73,
#   'deadCompare': 1},
#  {'name': '塞尔维亚',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 344,
#   'confirmAddCut': 0,
#   'confirm': 18983,
#   'suspect': 0,
#   'dead': 418,
#   'heal': 13991,
#   'nowConfirm': 4574,
#   'confirmCompare': 344,
#   'nowConfirmCompare': 280,
#   'healCompare': 51,
#   'deadCompare': 13},
#  {'name': '尼泊尔',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 116,
#   'confirmAddCut': 0,
#   'confirm': 17061,
#   'suspect': 0,
#   'dead': 38,
#   'heal': 10328,
#   'nowConfirm': 6695,
#   'confirmCompare': 116,
#   'nowConfirmCompare': 82,
#   'healCompare': 34,
#   'deadCompare': 0},
#  {'name': '摩洛哥',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 226,
#   'confirmAddCut': 0,
#   'confirm': 16047,
#   'suspect': 0,
#   'dead': 256,
#   'heal': 13403,
#   'nowConfirm': 2388,
#   'confirmCompare': 226,
#   'nowConfirmCompare': -504,
#   'healCompare': 727,
#   'deadCompare': 3},
#  {'name': '喀麦隆',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 15173,
#   'suspect': 0,
#   'dead': 359,
#   'heal': 11928,
#   'nowConfirm': 2886,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '乌兹别克斯坦',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 633,
#   'confirmAddCut': 0,
#   'confirm': 13993,
#   'suspect': 0,
#   'dead': 65,
#   'heal': 8074,
#   'nowConfirm': 5854,
#   'confirmCompare': 633,
#   'nowConfirmCompare': 408,
#   'healCompare': 222,
#   'deadCompare': 3},
#  {'name': '韩国',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 33,
#   'confirmAddCut': 0,
#   'confirm': 13512,
#   'suspect': 0,
#   'dead': 289,
#   'heal': 12282,
#   'nowConfirm': 941,
#   'confirmCompare': 33,
#   'nowConfirmCompare': -45,
#   'healCompare': 78,
#   'deadCompare': 0},
#  {'name': '丹麦',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 24,
#   'confirmAddCut': 0,
#   'confirm': 13262,
#   'suspect': 0,
#   'dead': 610,
#   'heal': 12361,
#   'nowConfirm': 291,
#   'confirmCompare': 24,
#   'nowConfirmCompare': -6,
#   'healCompare': 30,
#   'deadCompare': 0},
#  {'name': '捷克',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 64,
#   'confirmAddCut': 0,
#   'confirm': 13238,
#   'suspect': 0,
#   'dead': 353,
#   'heal': 8373,
#   'nowConfirm': 4512,
#   'confirmCompare': 64,
#   'nowConfirmCompare': -63,
#   'healCompare': 126,
#   'deadCompare': 1},
#  {'name': '科特迪瓦',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 106,
#   'confirmAddCut': 0,
#   'confirm': 12872,
#   'suspect': 0,
#   'dead': 84,
#   'heal': 6810,
#   'nowConfirm': 5978,
#   'confirmCompare': 106,
#   'nowConfirmCompare': -50,
#   'healCompare': 156,
#   'deadCompare': 0},
#  {'name': '吉尔吉斯斯坦',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 327,
#   'confirmAddCut': 0,
#   'confirm': 11444,
#   'suspect': 0,
#   'dead': 149,
#   'heal': 3538,
#   'nowConfirm': 7757,
#   'confirmCompare': 327,
#   'nowConfirmCompare': 247,
#   'healCompare': 78,
#   'deadCompare': 2},
#  {'name': '苏丹',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 66,
#   'confirmAddCut': 0,
#   'confirm': 10316,
#   'suspect': 0,
#   'dead': 657,
#   'heal': 5403,
#   'nowConfirm': 4256,
#   'confirmCompare': 66,
#   'nowConfirmCompare': -3,
#   'healCompare': 62,
#   'deadCompare': 7},
#  {'name': '萨尔瓦多',
#   'continent': '北美洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 325,
#   'confirmAddCut': 0,
#   'confirm': 10303,
#   'suspect': 0,
#   'dead': 278,
#   'heal': 5919,
#   'nowConfirm': 4106,
#   'confirmCompare': 325,
#   'nowConfirmCompare': 127,
#   'healCompare': 187,
#   'deadCompare': 11},
#  {'name': '肯尼亚',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 10294,
#   'suspect': 0,
#   'dead': 197,
#   'heal': 2946,
#   'nowConfirm': 7151,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '澳大利亚',
#   'continent': '大洋洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 271,
#   'confirmAddCut': 0,
#   'confirm': 10251,
#   'suspect': 0,
#   'dead': 110,
#   'heal': 7835,
#   'nowConfirm': 2306,
#   'confirmCompare': 271,
#   'nowConfirmCompare': 203,
#   'healCompare': 66,
#   'deadCompare': 2},
#  {'name': '委内瑞拉',
#   'continent': '南美洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 242,
#   'confirmAddCut': 0,
#   'confirm': 9707,
#   'suspect': 0,
#   'dead': 93,
#   'heal': 2671,
#   'nowConfirm': 6943,
#   'confirmCompare': 242,
#   'nowConfirmCompare': 238,
#   'healCompare': 0,
#   'deadCompare': 4},
#  {'name': '挪威',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 3,
#   'confirmAddCut': 0,
#   'confirm': 8984,
#   'suspect': 0,
#   'dead': 253,
#   'heal': 8138,
#   'nowConfirm': 593,
#   'confirmCompare': 3,
#   'nowConfirmCompare': 3,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '马来西亚',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 4,
#   'confirmAddCut': 0,
#   'confirm': 8729,
#   'suspect': 0,
#   'dead': 122,
#   'heal': 8524,
#   'nowConfirm': 83,
#   'confirmCompare': 4,
#   'nowConfirmCompare': 0,
#   'healCompare': 4,
#   'deadCompare': 0},
#  {'name': '塞内加尔',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 45,
#   'confirmAddCut': 0,
#   'confirm': 8243,
#   'suspect': 0,
#   'dead': 150,
#   'heal': 5580,
#   'nowConfirm': 2513,
#   'confirmCompare': 45,
#   'nowConfirmCompare': -21,
#   'healCompare': 66,
#   'deadCompare': 0},
#  {'name': '北马其顿',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 8197,
#   'suspect': 0,
#   'dead': 385,
#   'heal': 4326,
#   'nowConfirm': 3486,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '刚果（金）',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 60,
#   'confirmAddCut': 0,
#   'confirm': 8135,
#   'suspect': 0,
#   'dead': 190,
#   'heal': 3948,
#   'nowConfirm': 3997,
#   'confirmCompare': 60,
#   'nowConfirmCompare': -268,
#   'healCompare': 328,
#   'deadCompare': 0},
#  {'name': '哥斯达黎加',
#   'continent': '北美洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 440,
#   'confirmAddCut': 0,
#   'confirm': 8036,
#   'suspect': 0,
#   'dead': 34,
#   'heal': 2304,
#   'nowConfirm': 5698,
#   'confirmCompare': 440,
#   'nowConfirmCompare': 371,
#   'healCompare': 65,
#   'deadCompare': 4},
#  {'name': '埃塞俄比亚',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 7766,
#   'suspect': 0,
#   'dead': 128,
#   'heal': 2430,
#   'nowConfirm': 5208,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '保加利亚',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 159,
#   'confirmAddCut': 0,
#   'confirm': 7411,
#   'suspect': 0,
#   'dead': 276,
#   'heal': 3517,
#   'nowConfirm': 3618,
#   'confirmCompare': 159,
#   'nowConfirmCompare': -47,
#   'healCompare': 198,
#   'deadCompare': 8},
#  {'name': '芬兰',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 6,
#   'confirmAddCut': 0,
#   'confirm': 7301,
#   'suspect': 0,
#   'dead': 329,
#   'heal': 6800,
#   'nowConfirm': 172,
#   'confirmCompare': 6,
#   'nowConfirmCompare': 6,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '波黑',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 6981,
#   'suspect': 0,
#   'dead': 226,
#   'heal': 3179,
#   'nowConfirm': 3576,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '巴勒斯坦',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 291,
#   'confirmAddCut': 0,
#   'confirm': 6764,
#   'suspect': 0,
#   'dead': 42,
#   'heal': 1084,
#   'nowConfirm': 5638,
#   'confirmCompare': 291,
#   'nowConfirmCompare': 287,
#   'healCompare': 0,
#   'deadCompare': 4},
#  {'name': '海地',
#   'continent': '北美洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 6727,
#   'suspect': 0,
#   'dead': 141,
#   'heal': 3022,
#   'nowConfirm': 3564,
#   'confirmCompare': 0,
#   'nowConfirmCompare': -100,
#   'healCompare': 98,
#   'deadCompare': 2},
#  {'name': '塔吉克斯坦',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 44,
#   'confirmAddCut': 0,
#   'confirm': 6596,
#   'suspect': 0,
#   'dead': 55,
#   'heal': 5278,
#   'nowConfirm': 1263,
#   'confirmCompare': 44,
#   'nowConfirmCompare': -6,
#   'healCompare': 50,
#   'deadCompare': 0},
#  {'name': '几内亚',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 6141,
#   'suspect': 0,
#   'dead': 37,
#   'heal': 4862,
#   'nowConfirm': 1242,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '加蓬',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 84,
#   'confirmAddCut': 0,
#   'confirm': 6026,
#   'suspect': 0,
#   'dead': 46,
#   'heal': 3475,
#   'nowConfirm': 2505,
#   'confirmCompare': 84,
#   'nowConfirmCompare': -387,
#   'healCompare': 471,
#   'deadCompare': 0},
#  {'name': '毛里塔尼亚',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 91,
#   'confirmAddCut': 0,
#   'confirm': 5446,
#   'suspect': 0,
#   'dead': 147,
#   'heal': 2501,
#   'nowConfirm': 2798,
#   'confirmCompare': 91,
#   'nowConfirmCompare': -47,
#   'healCompare': 138,
#   'deadCompare': 0},
#  {'name': '马达加斯加',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 263,
#   'confirmAddCut': 0,
#   'confirm': 5343,
#   'suspect': 0,
#   'dead': 39,
#   'heal': 2646,
#   'nowConfirm': 2658,
#   'confirmCompare': 263,
#   'nowConfirmCompare': 109,
#   'healCompare': 152,
#   'deadCompare': 2},
#  {'name': '吉布提',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 5,
#   'confirmAddCut': 0,
#   'confirm': 4977,
#   'suspect': 0,
#   'dead': 56,
#   'heal': 4729,
#   'nowConfirm': 192,
#   'confirmCompare': 5,
#   'nowConfirmCompare': -12,
#   'healCompare': 17,
#   'deadCompare': 0},
#  {'name': '卢森堡',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 31,
#   'confirmAddCut': 0,
#   'confirm': 4956,
#   'suspect': 0,
#   'dead': 111,
#   'heal': 4183,
#   'nowConfirm': 662,
#   'confirmCompare': 31,
#   'nowConfirmCompare': -66,
#   'healCompare': 97,
#   'deadCompare': 0},
#  {'name': '中非共和国',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 33,
#   'confirmAddCut': 0,
#   'confirm': 4321,
#   'suspect': 0,
#   'dead': 53,
#   'heal': 1208,
#   'nowConfirm': 3060,
#   'confirmCompare': 33,
#   'nowConfirmCompare': -30,
#   'healCompare': 63,
#   'deadCompare': 0},
#  {'name': '匈牙利',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 11,
#   'confirmAddCut': 0,
#   'confirm': 4258,
#   'suspect': 0,
#   'dead': 595,
#   'heal': 3106,
#   'nowConfirm': 557,
#   'confirmCompare': 11,
#   'nowConfirmCompare': -22,
#   'healCompare': 33,
#   'deadCompare': 0},
#  {'name': '克罗地亚',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 52,
#   'confirmAddCut': 0,
#   'confirm': 3827,
#   'suspect': 0,
#   'dead': 120,
#   'heal': 2558,
#   'nowConfirm': 1149,
#   'confirmCompare': 52,
#   'nowConfirmCompare': 7,
#   'healCompare': 44,
#   'deadCompare': 1},
#  {'name': '希腊',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 23,
#   'confirmAddCut': 0,
#   'confirm': 3826,
#   'suspect': 0,
#   'dead': 193,
#   'heal': 1374,
#   'nowConfirm': 2259,
#   'confirmCompare': 23,
#   'nowConfirmCompare': 23,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '阿尔巴尼亚',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 96,
#   'confirmAddCut': 0,
#   'confirm': 3667,
#   'suspect': 0,
#   'dead': 97,
#   'heal': 2062,
#   'nowConfirm': 1508,
#   'confirmCompare': 96,
#   'nowConfirmCompare': 46,
#   'healCompare': 48,
#   'deadCompare': 2},
#  {'name': '泰国',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 7,
#   'confirmAddCut': 0,
#   'confirm': 3227,
#   'suspect': 0,
#   'dead': 58,
#   'heal': 3091,
#   'nowConfirm': 78,
#   'confirmCompare': 7,
#   'nowConfirmCompare': 6,
#   'healCompare': 1,
#   'deadCompare': 0},
#  {'name': '索马里',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 13,
#   'confirmAddCut': 0,
#   'confirm': 3072,
#   'suspect': 0,
#   'dead': 93,
#   'heal': 1343,
#   'nowConfirm': 1636,
#   'confirmCompare': 13,
#   'nowConfirmCompare': -66,
#   'healCompare': 79,
#   'deadCompare': 0},
#  {'name': '赤道几内亚',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 3071,
#   'suspect': 0,
#   'dead': 51,
#   'heal': 842,
#   'nowConfirm': 2178,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '巴拉圭',
#   'continent': '南美洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 32,
#   'confirmAddCut': 0,
#   'confirm': 2980,
#   'suspect': 0,
#   'dead': 25,
#   'heal': 1293,
#   'nowConfirm': 1662,
#   'confirmCompare': 32,
#   'nowConfirmCompare': 11,
#   'healCompare': 18,
#   'deadCompare': 3},
#  {'name': '尼加拉瓜',
#   'continent': '北美洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 2846,
#   'suspect': 0,
#   'dead': 91,
#   'heal': 1993,
#   'nowConfirm': 762,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '马尔代夫',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 31,
#   'confirmAddCut': 0,
#   'confirm': 2762,
#   'suspect': 0,
#   'dead': 13,
#   'heal': 2290,
#   'nowConfirm': 459,
#   'confirmCompare': 31,
#   'nowConfirmCompare': 25,
#   'healCompare': 6,
#   'deadCompare': 0},
#  {'name': '斯里兰卡',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 20,
#   'confirmAddCut': 0,
#   'confirm': 2651,
#   'suspect': 0,
#   'dead': 11,
#   'heal': 1988,
#   'nowConfirm': 652,
#   'confirmCompare': 20,
#   'nowConfirmCompare': 13,
#   'healCompare': 7,
#   'deadCompare': 0},
#  {'name': '马拉维',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 66,
#   'confirmAddCut': 0,
#   'confirm': 2430,
#   'suspect': 0,
#   'dead': 39,
#   'heal': 747,
#   'nowConfirm': 1644,
#   'confirmCompare': 66,
#   'nowConfirmCompare': -125,
#   'healCompare': 190,
#   'deadCompare': 1},
#  {'name': '古巴',
#   'continent': '北美洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 2428,
#   'suspect': 0,
#   'dead': 87,
#   'heal': 2268,
#   'nowConfirm': 73,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '马里',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 11,
#   'confirmAddCut': 0,
#   'confirm': 2423,
#   'suspect': 0,
#   'dead': 121,
#   'heal': 1748,
#   'nowConfirm': 554,
#   'confirmCompare': 11,
#   'nowConfirmCompare': -7,
#   'healCompare': 18,
#   'deadCompare': 0},
#  {'name': '黎巴嫩',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 85,
#   'confirmAddCut': 0,
#   'confirm': 2419,
#   'suspect': 0,
#   'dead': 36,
#   'heal': 1423,
#   'nowConfirm': 960,
#   'confirmCompare': 85,
#   'nowConfirmCompare': 82,
#   'healCompare': 3,
#   'deadCompare': 0},
#  {'name': '刚果（布）',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 2028,
#   'suspect': 0,
#   'dead': 47,
#   'heal': 589,
#   'nowConfirm': 1392,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '爱沙尼亚',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 1,
#   'confirmAddCut': 0,
#   'confirm': 2015,
#   'suspect': 0,
#   'dead': 69,
#   'heal': 1897,
#   'nowConfirm': 49,
#   'confirmCompare': 1,
#   'nowConfirmCompare': -1,
#   'healCompare': 2,
#   'deadCompare': 0},
#  {'name': '斯洛伐克',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 6,
#   'confirmAddCut': 0,
#   'confirm': 1908,
#   'suspect': 0,
#   'dead': 28,
#   'heal': 1493,
#   'nowConfirm': 387,
#   'confirmCompare': 6,
#   'nowConfirmCompare': 6,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '冰岛',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 5,
#   'confirmAddCut': 0,
#   'confirm': 1905,
#   'suspect': 0,
#   'dead': 10,
#   'heal': 1882,
#   'nowConfirm': 13,
#   'confirmCompare': 5,
#   'nowConfirmCompare': -6,
#   'healCompare': 11,
#   'deadCompare': 0},
#  {'name': '赞比亚',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 1895,
#   'suspect': 0,
#   'dead': 42,
#   'heal': 1412,
#   'nowConfirm': 441,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '立陶宛',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 1,
#   'confirmAddCut': 0,
#   'confirm': 1875,
#   'suspect': 0,
#   'dead': 79,
#   'heal': 1571,
#   'nowConfirm': 225,
#   'confirmCompare': 1,
#   'nowConfirmCompare': 1,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '斯洛文尼亚',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 10,
#   'confirmAddCut': 0,
#   'confirm': 1859,
#   'suspect': 0,
#   'dead': 111,
#   'heal': 1488,
#   'nowConfirm': 260,
#   'confirmCompare': 10,
#   'nowConfirmCompare': -5,
#   'healCompare': 15,
#   'deadCompare': 0},
#  {'name': '几内亚比绍',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 1842,
#   'suspect': 0,
#   'dead': 26,
#   'heal': 773,
#   'nowConfirm': 1043,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '佛得角',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 24,
#   'confirmAddCut': 0,
#   'confirm': 1722,
#   'suspect': 0,
#   'dead': 19,
#   'heal': 772,
#   'nowConfirm': 931,
#   'confirmCompare': 24,
#   'nowConfirmCompare': 0,
#   'healCompare': 24,
#   'deadCompare': 0},
#  {'name': '塞拉利昂',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 7,
#   'confirmAddCut': 0,
#   'confirm': 1642,
#   'suspect': 0,
#   'dead': 63,
#   'heal': 1175,
#   'nowConfirm': 404,
#   'confirmCompare': 7,
#   'nowConfirmCompare': -14,
#   'healCompare': 21,
#   'deadCompare': 0},
#  {'name': '新西兰',
#   'continent': '大洋洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 1,
#   'confirmAddCut': 0,
#   'confirm': 1545,
#   'suspect': 0,
#   'dead': 22,
#   'heal': 1498,
#   'nowConfirm': 25,
#   'confirmCompare': 1,
#   'nowConfirmCompare': 0,
#   'healCompare': 1,
#   'deadCompare': 0},
#  {'name': '利比亚',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 79,
#   'confirmAddCut': 0,
#   'confirm': 1512,
#   'suspect': 0,
#   'dead': 40,
#   'heal': 367,
#   'nowConfirm': 1105,
#   'confirmCompare': 79,
#   'nowConfirmCompare': 52,
#   'healCompare': 26,
#   'deadCompare': 1},
#  {'name': '也门',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 33,
#   'confirmAddCut': 0,
#   'confirm': 1498,
#   'suspect': 0,
#   'dead': 424,
#   'heal': 675,
#   'nowConfirm': 399,
#   'confirmCompare': 33,
#   'nowConfirmCompare': 10,
#   'healCompare': 16,
#   'deadCompare': 7},
#  {'name': '斯威士兰',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 38,
#   'confirmAddCut': 0,
#   'confirm': 1389,
#   'suspect': 0,
#   'dead': 20,
#   'heal': 688,
#   'nowConfirm': 681,
#   'confirmCompare': 38,
#   'nowConfirmCompare': 18,
#   'healCompare': 20,
#   'deadCompare': 0},
#  {'name': '卢旺达',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 41,
#   'confirmAddCut': 0,
#   'confirm': 1378,
#   'suspect': 0,
#   'dead': 4,
#   'heal': 710,
#   'nowConfirm': 664,
#   'confirmCompare': 41,
#   'nowConfirmCompare': 15,
#   'healCompare': 26,
#   'deadCompare': 0},
#  {'name': '贝宁',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 1378,
#   'suspect': 0,
#   'dead': 26,
#   'heal': 557,
#   'nowConfirm': 795,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '突尼斯',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 1302,
#   'suspect': 0,
#   'dead': 50,
#   'heal': 1082,
#   'nowConfirm': 170,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '黑山',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 66,
#   'confirmAddCut': 0,
#   'confirm': 1287,
#   'suspect': 0,
#   'dead': 24,
#   'heal': 330,
#   'nowConfirm': 933,
#   'confirmCompare': 66,
#   'nowConfirmCompare': 60,
#   'healCompare': 5,
#   'deadCompare': 1},
#  {'name': '莫桑比克',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 62,
#   'confirmAddCut': 0,
#   'confirm': 1219,
#   'suspect': 0,
#   'dead': 9,
#   'heal': 369,
#   'nowConfirm': 841,
#   'confirmCompare': 62,
#   'nowConfirmCompare': 57,
#   'healCompare': 5,
#   'deadCompare': 0},
#  {'name': '约旦',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 4,
#   'confirmAddCut': 0,
#   'confirm': 1183,
#   'suspect': 0,
#   'dead': 10,
#   'heal': 1008,
#   'nowConfirm': 165,
#   'confirmCompare': 4,
#   'nowConfirmCompare': -7,
#   'healCompare': 11,
#   'deadCompare': 0},
#  {'name': '拉脱维亚',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 1174,
#   'suspect': 0,
#   'dead': 31,
#   'heal': 1022,
#   'nowConfirm': 121,
#   'confirmCompare': 0,
#   'nowConfirmCompare': -3,
#   'healCompare': 3,
#   'deadCompare': 0},
#  {'name': '尼日尔',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 1099,
#   'suspect': 0,
#   'dead': 68,
#   'heal': 992,
#   'nowConfirm': 39,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '乌干达',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 11,
#   'confirmAddCut': 0,
#   'confirm': 1040,
#   'suspect': 0,
#   'dead': 0,
#   'heal': 984,
#   'nowConfirm': 56,
#   'confirmCompare': 11,
#   'nowConfirmCompare': 4,
#   'healCompare': 7,
#   'deadCompare': 0},
#  {'name': '布基纳法索',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 1,
#   'confirmAddCut': 0,
#   'confirm': 1037,
#   'suspect': 0,
#   'dead': 53,
#   'heal': 873,
#   'nowConfirm': 111,
#   'confirmCompare': 1,
#   'nowConfirmCompare': -3,
#   'healCompare': 4,
#   'deadCompare': 0},
#  {'name': '津巴布韦',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 49,
#   'confirmAddCut': 0,
#   'confirm': 1034,
#   'suspect': 0,
#   'dead': 19,
#   'heal': 343,
#   'nowConfirm': 672,
#   'confirmCompare': 49,
#   'nowConfirmCompare': 33,
#   'healCompare': 15,
#   'deadCompare': 1},
#  {'name': '利比里亚',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 1024,
#   'suspect': 0,
#   'dead': 51,
#   'heal': 439,
#   'nowConfirm': 534,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '塞浦路斯',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 1,
#   'confirmAddCut': 0,
#   'confirm': 1022,
#   'suspect': 0,
#   'dead': 19,
#   'heal': 839,
#   'nowConfirm': 164,
#   'confirmCompare': 1,
#   'nowConfirmCompare': 1,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '格鲁吉亚',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 4,
#   'confirmAddCut': 0,
#   'confirm': 999,
#   'suspect': 0,
#   'dead': 15,
#   'heal': 870,
#   'nowConfirm': 114,
#   'confirmCompare': 4,
#   'nowConfirmCompare': -9,
#   'healCompare': 13,
#   'deadCompare': 0},
#  {'name': '乌拉圭',
#   'continent': '南美洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 2,
#   'confirmAddCut': 0,
#   'confirm': 989,
#   'suspect': 0,
#   'dead': 31,
#   'heal': 903,
#   'nowConfirm': 55,
#   'confirmCompare': 2,
#   'nowConfirmCompare': -5,
#   'healCompare': 7,
#   'deadCompare': 0},
#  {'name': '乍得',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 880,
#   'suspect': 0,
#   'dead': 75,
#   'heal': 792,
#   'nowConfirm': 13,
#   'confirmCompare': 0,
#   'nowConfirmCompare': -2,
#   'healCompare': 2,
#   'deadCompare': 0},
#  {'name': '纳米比亚',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 3,
#   'confirmAddCut': 0,
#   'confirm': 864,
#   'suspect': 0,
#   'dead': 2,
#   'heal': 29,
#   'nowConfirm': 833,
#   'confirmCompare': 3,
#   'nowConfirmCompare': 1,
#   'healCompare': 1,
#   'deadCompare': 1},
#  {'name': '安道尔',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 3,
#   'confirmAddCut': 0,
#   'confirm': 858,
#   'suspect': 0,
#   'dead': 52,
#   'heal': 803,
#   'nowConfirm': 3,
#   'confirmCompare': 3,
#   'nowConfirmCompare': 3,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '苏里南',
#   'continent': '南美洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 18,
#   'confirmAddCut': 0,
#   'confirm': 780,
#   'suspect': 0,
#   'dead': 18,
#   'heal': 526,
#   'nowConfirm': 236,
#   'confirmCompare': 18,
#   'nowConfirmCompare': 1,
#   'healCompare': 17,
#   'deadCompare': 0},
#  {'name': '牙买加',
#   'continent': '北美洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 1,
#   'confirmAddCut': 0,
#   'confirm': 759,
#   'suspect': 0,
#   'dead': 10,
#   'heal': 628,
#   'nowConfirm': 121,
#   'confirmCompare': 1,
#   'nowConfirmCompare': -7,
#   'healCompare': 8,
#   'deadCompare': 0},
#  {'name': '多哥',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 1,
#   'confirmAddCut': 0,
#   'confirm': 721,
#   'suspect': 0,
#   'dead': 15,
#   'heal': 517,
#   'nowConfirm': 189,
#   'confirmCompare': 1,
#   'nowConfirmCompare': -3,
#   'healCompare': 4,
#   'deadCompare': 0},
#  {'name': '钻石号邮轮',
#   'continent': '其他',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 712,
#   'suspect': 0,
#   'dead': 13,
#   'heal': 651,
#   'nowConfirm': 48,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '圣马力诺',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 699,
#   'suspect': 0,
#   'dead': 42,
#   'heal': 656,
#   'nowConfirm': 1,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '马耳他',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 674,
#   'suspect': 0,
#   'dead': 9,
#   'heal': 660,
#   'nowConfirm': 5,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '安哥拉',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 19,
#   'confirmAddCut': 0,
#   'confirm': 525,
#   'suspect': 0,
#   'dead': 26,
#   'heal': 118,
#   'nowConfirm': 381,
#   'confirmCompare': 19,
#   'nowConfirmCompare': 19,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '坦桑尼亚',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 509,
#   'suspect': 0,
#   'dead': 21,
#   'heal': 183,
#   'nowConfirm': 305,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '叙利亚',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 417,
#   'suspect': 0,
#   'dead': 19,
#   'heal': 136,
#   'nowConfirm': 262,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '博茨瓦纳',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 399,
#   'suspect': 0,
#   'dead': 1,
#   'heal': 38,
#   'nowConfirm': 360,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '越南',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 1,
#   'confirmAddCut': 0,
#   'confirm': 373,
#   'suspect': 0,
#   'dead': 0,
#   'heal': 352,
#   'nowConfirm': 21,
#   'confirmCompare': 1,
#   'nowConfirmCompare': -1,
#   'healCompare': 2,
#   'deadCompare': 0},
#  {'name': '毛里求斯',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 342,
#   'suspect': 0,
#   'dead': 10,
#   'heal': 330,
#   'nowConfirm': 2,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '缅甸',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 5,
#   'confirmAddCut': 0,
#   'confirm': 336,
#   'suspect': 0,
#   'dead': 6,
#   'heal': 261,
#   'nowConfirm': 69,
#   'confirmCompare': 5,
#   'nowConfirmCompare': 5,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '科摩罗',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 317,
#   'suspect': 0,
#   'dead': 7,
#   'heal': 296,
#   'nowConfirm': 14,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '圭亚那',
#   'continent': '南美洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 3,
#   'confirmAddCut': 0,
#   'confirm': 300,
#   'suspect': 0,
#   'dead': 17,
#   'heal': 155,
#   'nowConfirm': 128,
#   'confirmCompare': 3,
#   'nowConfirmCompare': 2,
#   'healCompare': 1,
#   'deadCompare': 0},
#  {'name': '布隆迪',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 269,
#   'suspect': 0,
#   'dead': 1,
#   'heal': 207,
#   'nowConfirm': 61,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '莱索托',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 11,
#   'confirmAddCut': 0,
#   'confirm': 256,
#   'suspect': 0,
#   'dead': 3,
#   'heal': 48,
#   'nowConfirm': 205,
#   'confirmCompare': 11,
#   'nowConfirmCompare': -4,
#   'healCompare': 15,
#   'deadCompare': 0},
#  {'name': '蒙古',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 13,
#   'confirmAddCut': 0,
#   'confirm': 243,
#   'suspect': 0,
#   'dead': 0,
#   'heal': 204,
#   'nowConfirm': 39,
#   'confirmCompare': 13,
#   'nowConfirmCompare': 12,
#   'healCompare': 1,
#   'deadCompare': 0},
#  {'name': '厄立特里亚',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 232,
#   'suspect': 0,
#   'dead': 0,
#   'heal': 107,
#   'nowConfirm': 125,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '柬埔寨',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 9,
#   'confirmAddCut': 0,
#   'confirm': 165,
#   'suspect': 0,
#   'dead': 0,
#   'heal': 133,
#   'nowConfirm': 32,
#   'confirmCompare': 9,
#   'nowConfirmCompare': 9,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '文莱',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 141,
#   'suspect': 0,
#   'dead': 3,
#   'heal': 138,
#   'nowConfirm': 0,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '特立尼达和多巴哥',
#   'continent': '',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 133,
#   'suspect': 0,
#   'dead': 8,
#   'heal': 124,
#   'nowConfirm': 1,
#   'confirmCompare': 0,
#   'nowConfirmCompare': -4,
#   'healCompare': 4,
#   'deadCompare': 0},
#  {'name': '巴哈马',
#   'continent': '北美洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 2,
#   'confirmAddCut': 0,
#   'confirm': 113,
#   'suspect': 0,
#   'dead': 11,
#   'heal': 91,
#   'nowConfirm': 11,
#   'confirmCompare': 2,
#   'nowConfirmCompare': 0,
#   'healCompare': 2,
#   'deadCompare': 0},
#  {'name': '摩纳哥',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 109,
#   'suspect': 0,
#   'dead': 4,
#   'heal': 97,
#   'nowConfirm': 8,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '巴巴多斯',
#   'continent': '北美洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 103,
#   'suspect': 0,
#   'dead': 7,
#   'heal': 90,
#   'nowConfirm': 6,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '塞舌尔',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 100,
#   'suspect': 0,
#   'dead': 0,
#   'heal': 11,
#   'nowConfirm': 89,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '不丹',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 84,
#   'suspect': 0,
#   'dead': 0,
#   'heal': 78,
#   'nowConfirm': 6,
#   'confirmCompare': 0,
#   'nowConfirmCompare': -2,
#   'healCompare': 2,
#   'deadCompare': 0},
#  {'name': '列支敦士登公国',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 84,
#   'suspect': 0,
#   'dead': 1,
#   'heal': 81,
#   'nowConfirm': 2,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '安提瓜和巴布达',
#   'continent': '北美洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 74,
#   'suspect': 0,
#   'dead': 3,
#   'heal': 57,
#   'nowConfirm': 14,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '冈比亚',
#   'continent': '非洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 64,
#   'suspect': 0,
#   'dead': 3,
#   'heal': 34,
#   'nowConfirm': 27,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '马提尼克岛',
#   'continent': '北美洲',
#   'date': '03.23',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 37,
#   'suspect': 0,
#   'dead': 1,
#   'heal': 0,
#   'nowConfirm': 36,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '伯利兹',
#   'continent': '北美洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 37,
#   'suspect': 0,
#   'dead': 2,
#   'heal': 20,
#   'nowConfirm': 15,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '圣文森特和格林纳丁斯',
#   'continent': '北美洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 35,
#   'suspect': 0,
#   'dead': 0,
#   'heal': 29,
#   'nowConfirm': 6,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '斐济',
#   'continent': '大洋洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 26,
#   'suspect': 0,
#   'dead': 0,
#   'heal': 18,
#   'nowConfirm': 8,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '东帝汶',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 24,
#   'suspect': 0,
#   'dead': 0,
#   'heal': 24,
#   'nowConfirm': 0,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '格林纳达',
#   'continent': '北美洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 23,
#   'suspect': 0,
#   'dead': 0,
#   'heal': 23,
#   'nowConfirm': 0,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '圣卢西亚',
#   'continent': '北美洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 22,
#   'suspect': 0,
#   'dead': 0,
#   'heal': 19,
#   'nowConfirm': 3,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '老挝',
#   'continent': '亚洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 19,
#   'suspect': 0,
#   'dead': 0,
#   'heal': 19,
#   'nowConfirm': 0,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '多米尼克',
#   'continent': '北美洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 18,
#   'suspect': 0,
#   'dead': 0,
#   'heal': 18,
#   'nowConfirm': 0,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '圣基茨和尼维斯',
#   'continent': '北美洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 17,
#   'suspect': 0,
#   'dead': 0,
#   'heal': 15,
#   'nowConfirm': 2,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '梵蒂冈',
#   'continent': '欧洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 12,
#   'suspect': 0,
#   'dead': 0,
#   'heal': 12,
#   'nowConfirm': 0,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '巴布亚新几内亚',
#   'continent': '大洋洲',
#   'date': '07.14',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 11,
#   'suspect': 0,
#   'dead': 0,
#   'heal': 8,
#   'nowConfirm': 3,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0}]

# %% [markdown]
# # 外国部分国家历史每日数据（随时间变化）

# %%
# url6 = "https://api.inews.qq.com/newsqa/v1/automation/foreign/daily/list?country="

# 这里就会用到data5，其中name字段就是国家名
country_list = [c['name'] for c in data5] # 获取国家列表
for i in country_list:  
    # 请求每个国家的数据，这里并不是所有的国家都有统计每日数据
    # 因此最终只能得到部分国家的数据
    res6 = requests.get(url6+i, headers=headers2) 
    data6 = res6.json()['data'] # 提取具体数据
    
    if data6: # 当该国有数据的时候就存储下来
        # 可直接存储数据
        df_to_csv(pd.DataFrame(data6), filepath_fg+'/部分国家历史每日数据', f'{i}.csv')
        print(f"{i} 每日数据爬取OK")
    
    # 这里由于频繁请求，怕被封因此睡眠1秒
    time.sleep(1)
